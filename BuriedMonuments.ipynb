# %%
# !wget https://github.com/user-attachments/files/28442133/buried-monuments.zip > /dev/null 2>&1

# %%
# !unzip buried-monuments.zip

# %%
# !gcc buried_monuments.c cubiomes/*.c cubiomes/features/*.c -O3 -fwrapv -fopenmp -lm -lpthread -o buried_monuments

# %%
# !./buried_monuments --threads 24
