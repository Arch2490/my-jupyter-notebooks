# %% [markdown]
# ↓ get zip ↓

# %%
# !wget https://github.com/user-attachments/files/27159746/OOBMushy.zip > /dev/null 2>&1

# %% [markdown]
# ---

# %% [markdown]
# ↓ unzip it ↓

# %%
# !unzip OOBMushy.zip

# %% [markdown]
# ---

# %% [markdown]
# ↓ compile it ↓

# %%
# !gcc -O3 -march=native -ffast-math -funroll-loops -flto -fomit-frame-pointer -fstrict-aliasing -pthread main.c cubiomes/*.c -o main -lm -pthread

# %% [markdown]
# ---

# %% [markdown]
# ↓ run it ↓

# %%
# !./main

# %% [markdown]
# ---
