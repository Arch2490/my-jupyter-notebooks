# %% [markdown]
# # **ORIGINAL 12 EYE FINDER CODE MADE BY [ANDREW](https://github.com/Gaider10/12-eye)**
#
# ---

# %% [markdown]
# RUN THIS TO GET THE ZIP

# %%
# !wget https://github.com/user-attachments/files/24908797/archive.zip > /dev/null 2>&1

# %% [markdown]
# ---

# %% [markdown]
# RUN THIS TO UNZIP THE ZIP

# %%
# !unzip archive.zip

# %% [markdown]
# ---

# %% [markdown]
# RUN THIS TO COMPILE EVERYTHING

# %%
# !nvcc \
  src/eyefinder.cu \
  src/lib.cpp \
  src/xrsr.c \
  src/stronghold_generator/BoundingBox.cpp \
  src/stronghold_generator/Piece.cpp \
  src/stronghold_generator/PiecePlaceCount.cpp \
  src/stronghold_generator/PieceWeight.cpp \
  src/stronghold_generator/StrongholdGenerator.cpp \
  src/stronghold_generator/XrsrRandom.cpp \
  src/cubiomes/biomenoise.c \
  src/cubiomes/biomes.c \
  src/cubiomes/finders.c \
  src/cubiomes/generator.c \
  src/cubiomes/layers.c \
  src/cubiomes/noise.c \
  src/cubiomes/util.c \
  -o eyefinder \
  -O3 \
  -arch=sm_75 \
  --use_fast_math \
  -lineinfo \
  -maxrregcount 32

# %% [markdown]
# ---

# %% [markdown]
# RUN THIS BELOW TO RUN IT
#
#
#
# *   Use **--eyes** 1-12 to set the amount of eyes you want to search for (1-12)
# *   **--start** and **--end** to specify the start and end of the search
# * **--superflat** to instead search for the superflat world type
# * Use **--threads** to specify how much threads to use
#
# Thats pretty much all the important ones, you check all of them by going to src/eyefinder.cu
#
# Also just ignore the ones that say Valid: no. Idk why thats there so only look at the ones that say "YES"

# %%
# !./eyefinder --eyes 9

# %% [markdown]
# ---

# %% [markdown]
# *Ported to [Colab](https://colab.research.google.com/github/Arch2490/Eye-Finder/blob/main/EyeFinder.ipynb) (this one) and [Kaggle](https://www.kaggle.com/code/arch2490/eye-finder-kaggle/edit/run) by Arch2490/4rch249. All code is made by Andrew.*
