# %% [markdown]
# # loot_library.h but gpu
# loot_library.h is made by kris or scriptline i forgor, and ported to gpu by glowinggavin. made it into colab cuz i dont have a poop nvidia gpu so yeah

# %% [markdown]
# ---

# %% [markdown]
# run this thing below to get the zip

# %%
# !wget https://github.com/user-attachments/files/25822921/LootSeedFinder.zip > /dev/null 2>&1

# %% [markdown]
# ---

# %% [markdown]
# run this to unzip the thing

# %%
# !unzip LootSeedFinder.zip

# %% [markdown]
# ---

# %% [markdown]
# run this thing to compile, before compiling, go to src/cuda/gpu_scan.cu. change the loot table and version you want to search. you can also change the blocks, threads, and spt
# (this is important)

# %%
# !nvcc -O3 -std=c++17 -arch=sm_75 \
src/cuda/gpu_loot_table.cu \
src/cuda/gpu_scan.cu \
loot_table_context.o \
loot_table_parser.o \
loot_functions.o \
cJSON.o \
-Isrc -o gpu_scan

# %% [markdown]
# ---

# %% [markdown]
# run below to start searching for loot seeds on gpu. change the starting loot seed (just use 0), item name, and the min amount of that item

# %%
# !./gpu_scan <start_seed> <item_name> <item_amount>

# %% [markdown]
# ---
