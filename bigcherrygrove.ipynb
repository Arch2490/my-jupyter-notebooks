# %%
# !wget https://github.com/user-attachments/files/27473318/cherry.zip > /dev/null 2>&1

# %%
# !unzip cherry.zip
# Out:
# Archive:  cherry.zip
#    creating: cubiomes/
#    creating: cubiomes/.git/
#  extracting: cubiomes/.git/HEAD
#    creating: cubiomes/.git/branches/
#   inflating: cubiomes/.git/config
#   inflating: cubiomes/.git/description
#    creating: cubiomes/.git/hooks/
#   inflating: cubiomes/.git/hooks/applypatch-msg.sample
#   inflating: cubiomes/.git/hooks/commit-msg.sample
#   inflating: cubiomes/.git/hooks/fsmonitor-watchman.sample
#   inflating: cubiomes/.git/hooks/post-update.sample
#   inflating: cubiomes/.git/hooks/pre-applypatch.sample
#   inflating: cubiomes/.git/hooks/pre-commit.sample
#   inflating: cubiomes/.git/hooks/pre-merge-commit.sample
#   inflating: cubiomes/.git/hooks/pre-push.sample
#   inflating: cubiomes/.git/hooks/pre-rebase.sample
#   inflating: cubiomes/.git/hooks/pre-receive.sample
#   inflating: cubiomes/.git/hooks/prepare-commit-msg.sample
#   inflating: cubiomes/.git/hooks/push-to-checkout.sample
#   inflating: cubiomes/.git/hooks/sendemail-validate.sample
# ...

# %%
# !make
# Out:
# gcc -O3 -march=native -ffast-math -funroll-loops -flto -fomit-frame-pointer -fstrict-aliasing -pthread main.c cubiomes/biomenoise.c cubiomes/biomes.c cubiomes/finders.c cubiomes/generator.c cubiomes/layers.c cubiomes/noise.c cubiomes/quadbase.c cubiomes/util.c -o main -lm -pthread

# %%
# !./main
